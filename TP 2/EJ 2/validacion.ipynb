# %%
import random
import subprocess
from os import remove

# %%
iteraciones = 8
nroProcesadores = 5
numeros = []

# !mpicxx.mpich -o main.bin main.cpp
remove("datos/salida.csv")
with open("datos/salida.csv", "w") as salida:
    salida.write("ValorMax,RankPoseedor\n")
for i in range(iteraciones):
    numeros.append([])
    for j in range(nroProcesadores):
        factor = random.randint(1, 10)
        numeros[i].append(str(round(random.random()*factor, 2)))
    linea = ' '.join(numeros[i])
    with open("datos/datosInit.txt", "w") as archi:
        archi.write(linea)
    # !mpiexec.mpich -np $nroProcesadores ./main.bin
# Out:
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).
# hwloc/linux: Ignoring PCI device with non-16bit domain.
# Pass --enable-32bits-pci-domain to configure to support such devices
# (warning: it would break the library ABI, don't enable unless really needed).

# %%
def test(valorMax, rankPoseedor, numeros):
    numeros = [float(i) for i in numeros]
    print(valorMax , max(numeros))
    print(rankPoseedor , numeros.index(max(numeros)))
    return (valorMax == max(numeros) and rankPoseedor == numeros.index(max(numeros)))

# %%
numeros
# Out:
# [['0.53', '0.97', '4.0', '1.71', '3.34'],
#  ['0.42', '0.49', '1.88', '7.71', '1.02'],
#  ['3.28', '1.63', '1.8', '0.17', '1.95'],
#  ['2.24', '0.06', '1.88', '0.27', '0.62'],
#  ['0.51', '0.66', '4.02', '0.29', '0.05'],
#  ['0.43', '5.11', '0.96', '3.16', '6.58'],
#  ['7.81', '3.15', '4.29', '1.6', '1.76'],
#  ['2.16', '3.01', '2.29', '0.35', '5.08']]

# %%
import pandas as pd

df = pd.read_csv("datos/salida.csv")

i = 0
for _, row in df.iterrows():
    print(test(row["ValorMax"], row["RankPoseedor"], numeros[i]))
    i+=1
# Out:
# 4.0 4.0
# 2.0 2
# True
# 7.71 7.71
# 2.0 3
# False
# 3.28 3.28
# 0.0 0
# True
# 2.24 2.24
# 0.0 0
# True
# 4.02 4.02
# 2.0 2
# True
# 6.58 6.58
# 4.0 4
# True
# 7.81 7.81
# 0.0 0
# True
# 5.08 5.08
# 4.0 4
# True

# %%
lineas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/justo/Documentos/Facu/CAR/Practica-CAR/TP 2/EJ 2/validacion.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/home/justo/Documentos/Facu/CAR/Practica-CAR/TP%202/EJ%202/validacion.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> lineas
#
# NameError: name 'lineas' is not defined

# %%
df
# Out:
#    ValorMax  RankPoseedor
# 0      4.00             2
# 1      7.71             2
# 2      3.28             0
# 3      2.24             0
# 4      4.02             2
# 5      6.58             4
# 6      7.81             0
# 7      5.08             4
